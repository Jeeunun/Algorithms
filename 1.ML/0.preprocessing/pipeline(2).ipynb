# %% [markdown]
# ### **사용자 정의 함수 만들기**

# %%
import sklearn.base as base
import sklearn.preprocessing as skpre
import sklearn.pipeline as skpi
import sklearn.impute as skim
import sklearn.compose as skcom

# %% [markdown]
# ### **Class**

# %%
class Myclass:
    def __init__(self) -> None:
        self.result = 0

    def count(self,x:int,y:int):
        self.result = x**2+y**2
        return 'okay'

# %%
# 상위 클래스를 계승 받아 상위클래스의 기능을 사용할 수 있다.
class MysecondClass(Myclass):
    def __init__(self) -> None:
        super().__init__()
        self.result = 0
    def square(self, x):
        self.result+=x
        return 'okay'

# %% [markdown]
# ### **실습**

# %%
# sklearn호환성을 위해 base를 가져옴 -> sklearn의 baseestimator이며, transformerMixin(합치면서 활용-sklearn기반)
class Passthrough(base.BaseEstimator, base.TransformerMixin):
    # 기본 함수 정의
    def __init__(self) -> None:
        super().__init__()
        self.column_name = None
    # 학습 후 컬럼 이름을 저장해 놓는 함수 정의 (pipeline은 컬럼이름을 기억하지 못하기 때문에 저장해놓는 것이 좋다.)
    def fit(self, x):
        self.column_name=list(x.columns)            
        return self
    # 저장해 놓은 컬럼 이름을 호출하는 함수 정의
    def get_feature_names_out(self ,x=None):
        return self.column_name
    # sklearn 기반으로 TransformerMixin 할건데, 지금 함수에서는 passthrough라는 함수니까 아무것도 하지말고 input값 그대로 출력해 -> x.values
    def transform(self, x):
        return x.values

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('./train.csv')
# 종속변수
target = 'TARGET'
# 연속형 변수만
num_selector = df.select_dtypes(np.number).columns.difference([target])
# 범주형 변수만
cate_selector = df.select_dtypes('object').columns.difference(['sessionID'])
drop_cols = 'sessionID'

# %%
passthrough = Passthrough()

# %%
passthrough
# Out:
# Passthrough()

# %%
num_pipe = skpi.make_pipeline(
    skim.SimpleImputer(strategy='median'), #nan값은 중앙값으로
    skpre.StandardScaler()                 #scaling
    )

cate_pipe = skpi.make_pipeline(
    skim.SimpleImputer(strategy='most_frequent'),
    skpre.OneHotEncoder(handle_unknown='ignore', drop='first', sparse_output=False)   #sparse_output=False : 희소행렬은 제외
)

target_pipe = Passthrough()

total_pipe = skcom.make_column_transformer(
    (num_pipe, num_selector),
    (cate_pipe, cate_selector),
    (target_pipe, [target]),
    remainder='drop'
)

# %%
total_pipe
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  Index(['bounced', 'duration', 'new', 'quality', 'transaction',
#        'transaction_revenue'],
#       dtype='object')),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  Index(['OS', 'browser', 'continent', 'country', 'device', 'keyword',
#        'referral_path', 'subcontinent', 'traffic_medium', 'traffic_source',
#        'userID'],
#       dtype='object')),
#                                 ('passthrough', Passthrough(), ['TARGET'])])

# %%
total_pipe.fit(df.head(500))
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  Index(['bounced', 'duration', 'new', 'quality', 'transaction',
#        'transaction_revenue'],
#       dtype='object')),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  Index(['OS', 'browser', 'continent', 'country', 'device', 'keyword',
#        'referral_path', 'subcontinent', 'traffic_medium', 'traffic_source',
#        'userID'],
#       dtype='object')),
#                                 ('passthrough', Passthrough(), ['TARGET'])])

# %%
total_pipe.get_feature_names_out()
# Out:
# array(['pipeline-1__bounced', 'pipeline-1__duration', 'pipeline-1__new',
#        'pipeline-1__quality', 'pipeline-1__transaction',
#        'pipeline-1__transaction_revenue', 'pipeline-2__OS_Android',
#        'pipeline-2__OS_BlackBerry', 'pipeline-2__OS_Chrome OS',
#        'pipeline-2__OS_Linux', 'pipeline-2__OS_Macintosh',
#        'pipeline-2__OS_Tizen', 'pipeline-2__OS_Windows',
#        'pipeline-2__OS_Xbox', 'pipeline-2__OS_iOS',
#        'pipeline-2__browser_Android Browser',
#        'pipeline-2__browser_Android Webview',
#        'pipeline-2__browser_BlackBerry', 'pipeline-2__browser_Chrome',
#        'pipeline-2__browser_Coc Coc', 'pipeline-2__browser_Edge',
#        'pipeline-2__browser_Firefox',
#        'pipeline-2__browser_Internet Explorer',
#        'pipeline-2__browser_Opera', 'pipeline-2__browser_Opera Mini',
#        'pipeline-2__browser_Safari',
#        'pipeline-2__browser_Safari (in-app)',
#        'pipeline-2__browser_Samsung Internet',
#        'pipeline-2__browser_UC Browser', 'pipeline-2__continent_Americas',
#        'pipeline-2__continent_Asia', 'pipeline-2__continent_Europe',
#        'pipeline-2__continent_Oceania', 'pipeline-2__country_Argentina',
#        'pipeline-2__country_Australia', 'pipeline-2__country_Austria',
#        'pipeline-2__country_Bangladesh', 'pipeline-2__country_Belgium',
#        'pipeline-2__country_Bolivia', 'pipeline-2__country_Brazil',
#        'pipeline-2__country_Bulgaria', 'pipeline-2__country_Canada',
#        'pipeline-2__country_China', 'pipeline-2__country_Colombia',
#        'pipeline-2__country_Czechia', 'pipeline-2__country_Ecuador',
#        'pipeline-2__country_Egypt', 'pipeline-2__country_El Salvador',
#        'pipeline-2__country_Finland', 'pipeline-2__country_France',
#        'pipeline-2__country_Germany', 'pipeline-2__country_Greece',
#        'pipeline-2__country_Hong Kong', 'pipeline-2__country_Hungary',
#        'pipeline-2__country_India', 'pipeline-2__country_Indonesia',
#        'pipeline-2__country_Ireland', 'pipeline-2__country_Israel',
#        'pipeline-2__country_Italy', 'pipeline-2__country_Japan',
#        'pipeline-2__country_Kenya', 'pipeline-2__country_Kuwait',
#        'pipeline-2__country_Laos', 'pipeline-2__country_Malaysia',
#        'pipeline-2__country_Mexico', 'pipeline-2__country_Nepal',
#        'pipeline-2__country_Netherlands',
#        'pipeline-2__country_New Zealand', 'pipeline-2__country_Pakistan',
#        'pipeline-2__country_Peru', 'pipeline-2__country_Philippines',
#        'pipeline-2__country_Poland', 'pipeline-2__country_Portugal',
#        'pipeline-2__country_Romania', 'pipeline-2__country_Russia',
#        'pipeline-2__country_Réunion', 'pipeline-2__country_Saudi Arabia',
#        'pipeline-2__country_Serbia', 'pipeline-2__country_Singapore',
#        'pipeline-2__country_South Africa',
#        'pipeline-2__country_South Korea', 'pipeline-2__country_Spain',
#        'pipeline-2__country_Sri Lanka', 'pipeline-2__country_Sweden',
#        'pipeline-2__country_Switzerland', 'pipeline-2__country_Taiwan',
#        'pipeline-2__country_Thailand', 'pipeline-2__country_Turkey',
#        'pipeline-2__country_Ukraine',
#        'pipeline-2__country_United Arab Emirates',
#        'pipeline-2__country_United Kingdom',
#        'pipeline-2__country_United States', 'pipeline-2__country_Vietnam',
#        'pipeline-2__device_mobile', 'pipeline-2__device_tablet',
#        'pipeline-2__keyword_Category11',
#        'pipeline-2__keyword_Category1_Keyword_000',
#        'pipeline-2__keyword_Category1_Keyword_001',
#        'pipeline-2__keyword_Category1_Keyword_002',
#        'pipeline-2__keyword_Category1_Keyword_006',
#        'pipeline-2__keyword_Category2_Keyword_004',
#        'pipeline-2__keyword_Category2_Keyword_005',
#        'pipeline-2__keyword_Category2_Keyword_007',
#        'pipeline-2__keyword_Category2_Keyword_008',
#        'pipeline-2__keyword_Category2_Keyword_009',
#        'pipeline-2__keyword_Category6_Keyword_003',
#        'pipeline-2__keyword_Category8', 'pipeline-2__keyword_Category9',
#        'pipeline-2__referral_path_Category11_Path_0003',
#        'pipeline-2__referral_path_Category11_Path_0012',
#        'pipeline-2__referral_path_Category11_Path_0019',
#        'pipeline-2__referral_path_Category11_Path_0020',
#        'pipeline-2__referral_path_Category11_Path_0028',
#        'pipeline-2__referral_path_Category11_Path_0030',
#        'pipeline-2__referral_path_Category11_Path_0037',
#        'pipeline-2__referral_path_Category11_Path_0045',
#        'pipeline-2__referral_path_Category11_Path_0053',
#        'pipeline-2__referral_path_Category11_Path_0054',
#        'pipeline-2__referral_path_Category12_Path_0024',
#        'pipeline-2__referral_path_Category12_Path_0034',
#        'pipeline-2__referral_path_Category12_Path_0046',
#        'pipeline-2__referral_path_Category13_Path_0007',
#        'pipeline-2__referral_path_Category13_Path_0009',
#        'pipeline-2__referral_path_Category13_Path_0014',
#        'pipeline-2__referral_path_Category13_Path_0021',
#        'pipeline-2__referral_path_Category13_Path_0022',
#        'pipeline-2__referral_path_Category13_Path_0029',
#        'pipeline-2__referral_path_Category13_Path_0039',
#        'pipeline-2__referral_path_Category13_Path_0043',
#        'pipeline-2__referral_path_Category13_Path_0044',
#        'pipeline-2__referral_path_Category2_Path_0010',
#        'pipeline-2__referral_path_Category2_Path_0018',
#        'pipeline-2__referral_path_Category2_Path_0041',
#        'pipeline-2__referral_path_Category3_Path_0013',
#        'pipeline-2__referral_path_Category4_Path_0016',
#        'pipeline-2__referral_path_Category4_Path_0026',
#        'pipeline-2__referral_path_Category4_Path_0031',
#        'pipeline-2__referral_path_Category4_Path_0051',
#        'pipeline-2__referral_path_Category4_Path_0055',
#        'pipeline-2__referral_path_Category5_Path_0002',
#        'pipeline-2__referral_path_Category5_Path_0006',
#        'pipeline-2__referral_path_Category5_Path_0015',
#        'pipeline-2__referral_path_Category5_Path_0023',
#        'pipeline-2__referral_path_Category5_Path_0032',
#        'pipeline-2__referral_path_Category5_Path_0035',
#        'pipeline-2__referral_path_Category5_Path_0036',
#        'pipeline-2__referral_path_Category5_Path_0038',
#        'pipeline-2__referral_path_Category6_Path_0000',
#        'pipeline-2__referral_path_Category6_Path_0008',
#        'pipeline-2__referral_path_Category6_Path_0027',
#        'pipeline-2__referral_path_Category6_Path_0033',
#        'pipeline-2__referral_path_Category6_Path_0040',
#        'pipeline-2__referral_path_Category6_Path_0042',
#        'pipeline-2__referral_path_Category6_Path_0048',
#        'pipeline-2__referral_path_Category6_Path_0049',
#        'pipeline-2__referral_path_Category6_Path_0050',
#        'pipeline-2__referral_path_Category7_Path_0001',
#        'pipeline-2__referral_path_Category8_Path_0004',
#        'pipeline-2__referral_path_Category8_Path_0011',
#        'pipeline-2__referral_path_Category8_Path_0017',
#        'pipeline-2__referral_path_Category8_Path_0025',
#        'pipeline-2__referral_path_Category8_Path_0047',
#        'pipeline-2__referral_path_Category8_Path_0052',
#        'pipeline-2__referral_path_Category9_Path_0005',
#        'pipeline-2__subcontinent_Central America',
#        'pipeline-2__subcontinent_Eastern Africa',
#        'pipeline-2__subcontinent_Eastern Asia',
#        'pipeline-2__subcontinent_Eastern Europe',
#        'pipeline-2__subcontinent_Northern Africa',
#        'pipeline-2__subcontinent_Northern America',
#        'pipeline-2__subcontinent_Northern Europe',
#        'pipeline-2__subcontinent_South America',
#        'pipeline-2__subcontinent_Southeast Asia',
#        'pipeline-2__subcontinent_Southern Africa',
#        'pipeline-2__subcontinent_Southern Asia',
#        'pipeline-2__subcontinent_Southern Europe',
#        'pipeline-2__subcontinent_Western Asia',
#        'pipeline-2__subcontinent_Western Europe',
#        'pipeline-2__traffic_medium_affiliate',
#        'pipeline-2__traffic_medium_cpc', 'pipeline-2__traffic_medium_cpm',
#        'pipeline-2__traffic_medium_organic',
#        'pipeline-2__traffic_medium_referral',
#        'pipeline-2__traffic_source_Partners',
#        'pipeline-2__traffic_source_analytics.google.com',
#        'pipeline-2__traffic_source_baidu',
#        'pipeline-2__traffic_source_bing',
#        'pipeline-2__traffic_source_blog.golang.org',
#        'pipeline-2__traffic_source_dealspotr.com',
#        'pipeline-2__traffic_source_google',
#        'pipeline-2__traffic_source_google.co.jp',
#        'pipeline-2__traffic_source_google.com',
#        'pipeline-2__traffic_source_googleads.g.doubleclick.net',
#        'pipeline-2__traffic_source_groups.google.com',
#        'pipeline-2__traffic_source_l.facebook.com',
#        'pipeline-2__traffic_source_mail.google.com',
#        'pipeline-2__traffic_source_pinterest.com',
#        'pipeline-2__traffic_source_qiita.com',
#        'pipeline-2__traffic_source_quora.com',
#        'pipeline-2__traffic_source_reddit.com',
#        'pipeline-2__traffic_source_sites.google.com',
#        'pipeline-2__traffic_source_youtube.com',
#        'pipeline-2__userID_USER_000001', 'pipeline-2__userID_USER_000002',
#        'pipeline-2__userID_USER_000003', 'pipeline-2__userID_USER_000004',
#        'pipeline-2__userID_USER_000005', 'pipeline-2__userID_USER_000006',
#        'pipeline-2__userID_USER_000399', 'pipeline-2__userID_USER_000400',
#        'pipeline-2__userID_USER_000401', 'pipeline-2__userID_USER_000402',
#        'pipeline-2__userID_USER_000403', 'pipeline-2__userID_USER_000404',
#        'pipeline-2__userID_USER_000405', 'pipeline-2__userID_USER_000406',
#        'pipeline-2__userID_USER_000407', 'pipeline-2__userID_USER_000408',
#        'pipeline-2__userID_USER_000409', 'pipeline-2__userID_USER_000410',
#        'pipeline-2__userID_USER_000411', 'pipeline-2__userID_USER_000412',
#        'pipeline-2__userID_USER_000413', 'pipeline-2__userID_USER_000414',
#        'pipeline-2__userID_USER_000415', 'pipeline-2__userID_USER_000416',
#        'pipeline-2__userID_USER_000417', 'pipeline-2__userID_USER_000418',
#        'pipeline-2__userID_USER_000419', 'pipeline-2__userID_USER_000420',
#        'pipeline-2__userID_USER_000421', 'pipeline-2__userID_USER_000422',
#        'pipeline-2__userID_USER_000423', 'pipeline-2__userID_USER_000424',
#        'pipeline-2__userID_USER_000425', 'pipeline-2__userID_USER_000426',
#        'pipeline-2__userID_USER_000427', 'pipeline-2__userID_USER_000428',
#        'pipeline-2__userID_USER_000429', 'pipeline-2__userID_USER_000430',
#        'pipeline-2__userID_USER_000431', 'pipeline-2__userID_USER_000432',
#        'pipeline-2__userID_USER_000433', 'pipeline-2__userID_USER_000434',
#        'pipeline-2__userID_USER_000435', 'pipeline-2__userID_USER_000436',
#        'pipeline-2__userID_USER_000437', 'pipeline-2__userID_USER_000438',
#        'pipeline-2__userID_USER_000439', 'pipeline-2__userID_USER_000440',
#        'pipeline-2__userID_USER_000441', 'pipeline-2__userID_USER_000442',
#        'pipeline-2__userID_USER_000443', 'pipeline-2__userID_USER_000444',
#        'pipeline-2__userID_USER_000445', 'pipeline-2__userID_USER_000446',
#        'pipeline-2__userID_USER_000447', 'pipeline-2__userID_USER_000448',
#        'pipeline-2__userID_USER_000449', 'pipeline-2__userID_USER_000450',
#        'pipeline-2__userID_USER_000451', 'pipeline-2__userID_USER_000452',
#        'pipeline-2__userID_USER_000453', 'pipeline-2__userID_USER_000454',
#        'pipeline-2__userID_USER_000455', 'pipeline-2__userID_USER_000456',
#        'pipeline-2__userID_USER_000457', 'pipeline-2__userID_USER_000458',
#        'pipeline-2__userID_USER_000459', 'pipeline-2__userID_USER_000460',
#        'pipeline-2__userID_USER_000461', 'pipeline-2__userID_USER_000462',
#        'pipeline-2__userID_USER_000463', 'pipeline-2__userID_USER_000464',
#        'pipeline-2__userID_USER_000465', 'pipeline-2__userID_USER_000466',
#        'pipeline-2__userID_USER_000467', 'pipeline-2__userID_USER_000468',
#        'pipeline-2__userID_USER_000469', 'pipeline-2__userID_USER_000470',
#        'pipeline-2__userID_USER_000471', 'passthrough__TARGET'],
#       dtype=object)

# %%
total_pipe.named_transformers_.keys()
# Out:
# dict_keys(['pipeline-1', 'pipeline-2', 'passthrough', 'remainder'])
